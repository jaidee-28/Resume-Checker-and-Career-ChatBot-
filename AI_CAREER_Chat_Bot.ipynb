# %%
from langchain_openai import ChatOpenAI

# Initialize using OpenRouter's base URL
llm = ChatOpenAI(
    openai_api_key="sAPI kye",
    openai_api_base="https://openrouter.ai/api/v1",
    model_name="deepseek/deepseek-v4-flash-0731" # or any model on OpenRouter
)

# %%
import os
os.environ['api_kye']="API kye"

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings.openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10132\1222682122.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
"C:\Users\ADMIN\Downloads\image.pdf"

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(r"C:\Users\ADMIN\Downloads\image.pdf")
documents = loader.load()

context = "\n\n".join(doc.page_content for doc in documents)

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

chat_history = []

system_message = SystemMessage(
    content=f"""
    You are a professional career coach and resume mentor.

    You help with:
    - Career Guidance
    - Resume Improvements
    - Interview Preparation
    - Job Search Strategy
    - Skill Gap Analysis

    Candidate Resume:
    {context}
    """
)

# %%
while True:
  user_input = input("You: ")

  if user_input.lower() in ['exit', 'quit']:
    print("\n Goodbye!!")

  # Add user message to memory
  chat_history.append(HumanMessage(content=user_input))

  #Build message list
  messages = [system_message] + chat_history

  print("\nCoach:", end = " ", flush=True)

  response_text = ""

  for chunk in llm.stream(messages):
    print(chunk.content, end="",flush=True)
    response_text = response_text + chunk.content


  #Add AI response to memory
  chat_history.append(AIMessage(content=response_text))

  print("\n")
# Out:
# You:  what can be next career move, can u tell me
# Coach: Hi there! I’d love to help you figure out your next career move.
#
# To give you the most **accurate and personalized** recommendation, I need to see your specific background. Right now, I don’t have your resume or current role details in front of me.
#
# However, while you get that ready, here is a **general framework** to help you identify the best path forward. Career moves typically fall into one of these four categories:
#
# 1. **The Vertical Climb (Upgrade)**
#    *Moving to the next seniority level in your current field.*
#    - *Example:* Individual Contributor → Team Lead → Manager → Director.
#
# 2. **The Lateral Pivot (Side-step)**
#    *Moving into a different function or industry to gain new skills.*
#    - *Example:* Marketing → Product Management, or Finance → Tech Sales.
#
# 3. **The Specialization (Deep Dive)**
#    *Becoming an expert in a high-demand niche within your current domain.*
# ...

# %%
what can be next career move, can u tell me
