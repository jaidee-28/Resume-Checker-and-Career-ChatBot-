# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    openai_api_key="API kye",
    openai_api_base="https://openrouter.ai/api/v1",
    model_name="deepseek/deepseek-v4-flash-0731" 
)

# %%
import os
os.environ['api_kye']="API kye"

# %% [markdown]
# ## PDF Based RAG Chatbot

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(r"C:\Users\ADMIN\Downloads\image.pdf")
documents = loader.load()

context = "\n\n".join(doc.page_content for doc in documents)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16908\3745762591.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    You are an advanced resume evaluation assistant. Analyze the provided resume in the context document and
    score it out of 100 based on the following criteria: clarity, relevance, format, comprehensiveness, and keywords.

    Your response should be structured as follows:

    1. **Score**: Provide the score out of 100.
    2. **Strengths**: List at least three strengths found in the resume.
    3. **Weaknesses**: List at least three weaknesses or areas for improvement in the resume.
    4. **Skills Mentioned**: Identify and list the skills that are explicitly mentioned in the resume.
    5. **Recommended Skills**: Suggest additional skills that could enhance the resume's effectiveness.
    6. **Next Career Path**: Suggest what should be the next career paths for this candidate.

    Please ensure your analysis is clear and concise, providing actionable insights for improvement.
    """
)

# %%
# Prepare the question
question = "Please evaluate this resume."

formatted_prompt = prompt.format(context=context, question=question)

# %%
for m in llm.stream(formatted_prompt):
  print(m.content, end="", flush = True)
# Out:
# Based on the provided resume context, here is a comprehensive evaluation:
#
# **1. Score**: **72/100**
#
# **2. Strengths**:
# - **Clear Structure**: The resume is well-organized with distinct sections (Professional Summary, Skills, Experience, Education), making it easy for recruiters to scan.
# - **Action-Oriented Language**: Uses strong verbs like "Spearheaded," "Developed," and "Optimized," which convey a sense of ownership and impact.
# - **Quantifiable Achievements**: Includes specific metrics (e.g., "increased efficiency by 20%," "managed a budget of $500k"), which helps demonstrate tangible value to potential employers.
#
# **3. Weaknesses**:
# - **Lack of Tailoring**: The resume appears generic and does not seem customized for a specific job posting, which may reduce its relevance in a competitive job market.
# - **Missing Soft Skills**: While technical skills are highlighted, crucial soft skills such as leadership, communication, or teamwork are not explicitly mentioned, which are often key differentiators.
# - **Inconsistent Formatting**: The use of bullet points and spacing is inconsistent in the "Experience" section, which detracts from the overall professional appearance.
#
# **4. Skills Mentioned**:
# - Project Management
# - Data Analysis
# - Python
# - SQL
# - Agile Methodologies
# - Budget Management
# - Stakeholder Communication
# - Risk Assessment
#
# **5. Recommended Skills**:
# - **Cloud Computing (AWS/Azure)**: To stay current with industry trends and enhance technical versatility.
# - **Machine Learning**: To add a competitive edge, especially if the candidate is in a data-related field.
# - **Advanced Excel or BI Tools (Power BI, Tableau)**: To strengthen data visualization and reporting capabilities.
# - **Leadership & Team Management**: To prepare for senior roles and demonstrate people management potential.
#
# **6. Next Career Path**:
# - **Senior Project Manager**: Given the strong project management and budget experience, the candidate is well-positioned to move into a senior or program manager role.
# - **Data Analytics Manager**: With a solid foundation in data analysis and Python, transitioning to a managerial role in analytics would be a logical progression.
# - **Product Manager**: The combination of technical skills and stakeholder communication makes this a viable path, especially if the candidate gains more product lifecycle experience.
