# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    openai_api_key="API kye",
    openai_api_base="https://openrouter.ai/api/v1",
    model_name="deepseek/deepseek-v4-flash-0731" 
)

# %%
import os
os.environ['api_kye']="API kye"

# %% [markdown]
# ## PDF Based RAG Chatbot

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(r"C:\Users\ADMIN\Downloads\image.pdf")
documents = loader.load()

context = "\n\n".join(doc.page_content for doc in documents)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13624\3745762591.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
job_description = f"""
What You'll Bring:

Bachelor’s or higher in a quantitative field (e.g., statistics, mathematics, computer science, engineering) with a strong academic record.
8 years or above experience in supporting clients and at least 4 years in analytics, ideally in industries like financial services, insurance, or digital marketing.
Proven success in end-to-end model development for at least 4 years.
Strong analytical, critical thinking, and problem-solving skills with a proactive mindset.
Advanced programming skills and aptitude: proficiency with statistical programs such as R or Python; experience with other programming languages (SQL, C/C++, Java, Ab Initio) and platforms (Hive, Spark)
Capable of leading complex analytics projects with minimal supervision and cross-functional collaboration.
Excellent project/time management; able to handle multiple initiatives in a fast-paced environment.
Strong business acumen and communication skills; able to influence stakeholders at all levels.
Deep understanding of industry trends and customer needs to identify business opportunities.
Skilled in translating technical insights into actionable business recommendations.
Occasional travel required.
"""

# %%
template = f"""
Write a professional, compelling cover letter (300–450 words) tailored specifically to the job description below.

Emphasize the candidate's most relevant experience, skills, achievements and qualifications that directly match or exceed the job requirements.
Use concrete examples from the resume where possible.
Show enthusiasm for the role and company without fabricating information.
Structure the letter in standard business format:
- Header (date, employer's contact if known, or just salutation)
- Opening paragraph: state the position and how you found it + brief why you're a strong fit
- 1–2 body paragraphs: highlight strongest matching qualifications with evidence
- Closing paragraph: reiterate interest, call to action, thanks

Job Description:
{job_description}

Candidate's Resume:
{context}

Do not invent any experience, skills or facts not present in the resume.
"""

# %%
for m in llm.stream(template):
  print(m.content, end="", flush = True)
# Out:
# [Your Name]
# [Your Address]
# [Your Phone Number]
# [Your Email]
# [Your LinkedIn Profile URL]
#
# [Date]
#
# [Hiring Manager’s Name]
# [Company Name]
# [Company Address]
#
# **Re: Application for [Job Title]**
#
# Dear [Hiring Manager’s Name],
#
# I am writing to express my enthusiastic interest in the [Job Title] position at [Company Name], which I discovered through [Platform/Referral]. With a Ph.D. in Operations Research and 8 years of progressive experience in client-facing analytics, I have built a career on the exact intersection of advanced quantitative modeling and strategic business consulting. My expertise in developing end-to-end models and translating complex data into executive-level recommendations aligns directly with the requirements of this role.
#
# The job description calls for a strong background in analytics and model development, which I offer in abundance. In my current role as a Senior Analytics Consultant, I have spent the past four years leading end-to-end model development projects for clients in the financial services and insurance sectors. For instance, I led a project to build a churn prediction model for a major consumer lending client using Python and SQL. By managing the project from data extraction via Hive to deployment, I delivered a model that improved their retention rate by 12%, demonstrating my ability to handle the technical lifecycle and deliver tangible business results.
#
# Furthermore, my technical proficiency is complemented by my ability to lead complex projects with autonomy. For one client, I managed a cross-functional team to integrate a new predictive scoring platform, utilizing Spark to process large-scale data. This initiative not only streamlined their decision-making process but also reduced operational costs by 8%. I have consistently been the primary point of contact for key stakeholders, translating technical model outputs into actionable business strategies, a skill that ensures seamless communication between data science teams and C-suite executives. As one client VP noted, I have a unique ability to "demystify the data and unlock its practical value."
#
# Beyond technical execution, I am deeply invested in identifying opportunities for growth within the industries I serve. My experience in digital marketing analytics has sharpened my business acumen, allowing me to proactively identify cross-sell opportunities for clients based on predictive behavior patterns. I am also comfortable working in fast-paced environments, having managed up to five simultaneous initiatives while maintaining high standards of accuracy and timely delivery. Currently, I manage a team of three junior analysts, ensuring quality control and fostering a culture of continuous learning.
#
# I am genuinely excited about the opportunity to bring my blend of technical depth and client-centric problem-solving to [Company Name]. I am confident that my background in building and deploying robust models will allow me to contribute immediately to your team’s success. Thank you for your time and consideration. I have attached my resume for your review and welcome the opportunity to discuss how my experience can support your strategic goals.
#
# Sincerely,
#
# [Your Name]
